# %%
pip install ultralytics

# %% [markdown]
# from ultralytics import YOLO
#
# model = YOLO("yolov8n.pt")

# %% [markdown]
# model.train(
#     data="data.yaml",
#     epochs=50,
#     imgsz=640,
#     batch=16
# )

# %%
metrics = model.val()
print(metrics)

# %%
results = model("test.jpg")
results[0].show()
