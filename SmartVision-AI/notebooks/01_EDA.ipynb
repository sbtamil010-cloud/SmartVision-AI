# %%
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import numpy as np

# %%
with open("instances_train2017.json") as f:
    coco_data = json.load(f)

# %%
class_counts = {}

for ann in coco_data["annotations"]:
    class_counts[ann["category_id"]] = class_counts.get(ann["category_id"], 0) + 1

plt.figure(figsize=(12,6))
sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()))
plt.title("Class Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
img = cv2.imread("sample.jpg")
for bbox in annotations:
    x,y,w,h = bbox
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")

# %%
objects_per_image = {}

for ann in coco_data["annotations"]:
    img_id = ann["image_id"]
    objects_per_image[img_id] = objects_per_image.get(img_id,0)+1

plt.hist(objects_per_image.values(), bins=20)
plt.title("Objects per Image")
plt.show()
